# %% [markdown]
# <a href="https://colab.research.google.com/github/SebastianTrujillo21/Algoritmos_de_Ordenamiento/blob/develop/Algoritmos_de_Ordenamientos_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# %%
arreglo = []
for i in range(10000):
  arreglo.append(random.randint(1, 100000))

# %%
banda = False
while banda==False:
  banda = True
  for i in range(len(arreglo)-1):
    if arreglo[i]<arreglo[i+1]:
      aux = arreglo[i]
      arreglo[i] = arreglo[i+1]
      arreglo[i+1] = aux
      banda = False

print(arreglo)

# %%
arr = [124,531,12,3,2,0]
flag = False

while flag == False:
	flag = True
	for i in range(len(arr)-1):
		if arr[i]>arr[i+1]:
			aux = arr[i]
			arr[i] = arr[i+1]
			arr[i+1] = aux
			flag = False

print(arr)
# Out:
# [0, 2, 3, 12, 124, 531]
